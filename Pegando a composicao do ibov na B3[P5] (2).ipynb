# %% [markdown]
# # Composição do Ibovespa no site da B3 via WebScraping

# %%
pip install --upgrade selenium
# Out:
# Requirement already satisfied: selenium in c:\users\home\anaconda3\lib\site-packages (4.22.0)
# Collecting selenium
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/05/6e/ce2c7b3e822c4b349e963ea5b75ec7ae2b6e2c0ad4b8f946055629877e1d/selenium-4.23.0-py3-none-any.whl.metadata
#   Downloading selenium-4.23.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\home\anaconda3\lib\site-packages (from selenium) (1.26.18)
# Requirement already satisfied: trio~=0.17 in c:\users\home\anaconda3\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\home\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\home\anaconda3\lib\site-packages (from selenium) (2023.11.17)
# Collecting typing_extensions~=4.9.0 (from selenium)
#   Obtaining dependency information for typing_extensions~=4.9.0 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client==1.8.0 in c:\users\home\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\home\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\home\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\home\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\home\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.23.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.4 MB 9.2 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.4 MB 8.5 MB/s eta 0:00:01
#    ------------- -------------------------- 3.2/9.4 MB 6.4 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.4 MB 6.5 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.4 MB 6.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.4 MB 6.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.4 MB 6.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.4 MB 6.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.4 MB 6.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.4 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.3/9.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.0/9.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 2.9 MB/s eta 0:00:00
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: typing_extensions, selenium
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: selenium
#     Found existing installation: selenium 4.22.0
#     Uninstalling selenium-4.22.0:
#       Successfully uninstalled selenium-4.22.0
# Successfully installed selenium-4.23.0 typing_extensions-4.9.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder-kernels 2.4.4 requires ipykernel<7,>=6.23.2; python_version >= "3", but you have ipykernel 6.21.1 which is incompatible.

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from datetime import date
import os

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url = 'https://www.b3.com.br/pt_br/market-data-e-indices/indices/indices-amplos/indice-ibovespa-ibovespa-composicao-da-carteira.htm'

driver.get(url)

# %%
WebDriverWait(driver, 10).until(
    EC.frame_to_be_available_and_switch_to_it((By.ID, "bvmf_iframe")))

planilha = driver.find_element("xpath", '//*[@id="divContainerIframeB3"]/div/div[1]/form/div[2]/div/div[2]/div/div/div[1]/div[2]/p/a')

driver.execute_script("arguments[0].click();", planilha)

time.sleep(5)

driver.quit()

# %%
dia = date.today().day
mes = date.today().month
ano = date.today().year

# %%
if dia < 10:

    dia = "0" + str(dia)

if mes < 10:

    mes = "0" + str(mes)

ano = str(ano)[2:]

print(dia, mes, ano)
# Out:
# 02 08 24

# %%
caminho_downloads = r'C:\Users\Home\Downloads'

ibovespa_comp = pd.read_csv(caminho_downloads + fr"\IBOVDia_{dia}-{mes}-{ano}.csv", sep = ";", 
                        skipfooter = 2, encoding = 'ISO-8859-1', engine = 'python', decimal = ',',
                       thousands = ".", header = 1, index_col = False)

ibovespa_comp
# Out:
#    Código          Ação        Tipo  Qtde. Teórica  Part. (%)
# 0   RRRP3  3R PETROLEUM  ON      NM      238441689      0.303
# 1   ALOS3         ALLOS  ON      NM      532616595      0.556
# 2   ALPA4    ALPARGATAS  PN      N1      166362038      0.067
# 3   ABEV3     AMBEV S/A          ON     4394245879      2.445
# 4   ASAI3         ASSAI  ON      NM     1349217892      0.634
# ..    ...           ...         ...            ...        ...
# 80  VAMO3         VAMOS  ON      NM      498860020      0.200
# 81  VBBR3         VIBRA  ON      NM     1114613709      1.237
# 82  VIVA3   VIVARA S.A.  ON      NM      125912025      0.143
# 83  WEGE3           WEG  ON      NM     1482105837      3.712
# 84  YDUQ3    YDUQS PART  ON      NM      289347914      0.147
#
# [85 rows x 5 columns]

# %%
os.remove(caminho_downloads + fr"\IBOVDia_{dia}-{mes}-{ano}.csv")

ibovespa_comp.columns = ['codigos', 'nome', 'classe', 'qtd', 'part']

ibovespa_comp
# Out:
#    codigos          nome      classe         qtd   part
# 0    RRRP3  3R PETROLEUM  ON      NM   238441689  0.303
# 1    ALOS3         ALLOS  ON      NM   532616595  0.556
# 2    ALPA4    ALPARGATAS  PN      N1   166362038  0.067
# 3    ABEV3     AMBEV S/A          ON  4394245879  2.445
# 4    ASAI3         ASSAI  ON      NM  1349217892  0.634
# ..     ...           ...         ...         ...    ...
# 80   VAMO3         VAMOS  ON      NM   498860020  0.200
# 81   VBBR3         VIBRA  ON      NM  1114613709  1.237
# 82   VIVA3   VIVARA S.A.  ON      NM   125912025  0.143
# 83   WEGE3           WEG  ON      NM  1482105837  3.712
# 84   YDUQ3    YDUQS PART  ON      NM   289347914  0.147
#
# [85 rows x 5 columns]

# %%
ibovespa_comp.to_csv("comp_ibov_teste.csv", index = False)
