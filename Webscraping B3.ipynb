# %% [markdown]
# # Webscraping B3

# %% [markdown]
# # Web Scraping B3
#
# This Jupyter notebook demonstrates a web scraping project aimed at extracting financial data from the B3 (Brasil, Bolsa, Balcão) website using Selenium and BeautifulSoup. The notebook includes steps for data extraction, processing, and conversion of scraped dates into a suitable format for analysis.
#
# ## Features
#
# - **Web Scraping**: Utilizes Selenium for navigating the B3 website and extracting relevant financial data.
# - **Data Processing**: Employs Pandas for data manipulation and BeautifulSoup for parsing HTML.
# - **Date Conversion**: Converts the scraped date format into `pd.Timestamp` for better handling and analysis.
# - **Data Analysis**: Includes basic data analysis and visualization using Matplotlib and other relevant libraries.
#
# ## Prerequisites
#
# Before you begin, ensure you have met the following requirements:
#
# - Python 3.7 or higher
# - Jupyter Notebook
# - Selenium
# - BeautifulSoup4
# - Pandas
# - Matplotlib
# - ChromeDriver (compatible with your Chro3.git
#    cd webscraping-b3

# %%
# !pip install selenium 
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: selenium in c:\users\home\anaconda3\lib\site-packages (4.22.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\home\anaconda3\lib\site-packages (from selenium) (1.26.18)
# Requirement already satisfied: trio~=0.17 in c:\users\home\anaconda3\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\home\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\home\anaconda3\lib\site-packages (from selenium) (2023.11.17)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\home\anaconda3\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client>=1.8.0 in c:\users\home\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\home\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\home\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\home\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\home\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\home\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: webdriver-manager in c:\users\home\anaconda3\lib\site-packages (4.0.1)
# Requirement already satisfied: requests in c:\users\home\anaconda3\lib\site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\home\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\home\anaconda3\lib\site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\home\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\home\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\home\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\home\anaconda3\lib\site-packages (from requests->webdriver-manager) (2023.11.17)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service    #helps managing drives
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from datetime import datetime

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install())) 
# fix driver issues. Gets the latest browser release

# %% [markdown]
# ## Scraping Settings

# %%
date = "27/05/2024"

# %%
product = 'DI1'

# %%
url = f'''
https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/SistemaPregao1.asp?pagetype=pop&caminho=Resumo%20
Estat%EDstico%20-%20Sistema%20Preg%E3o&Data={date}&Mercadoria={product}
'''

# %%
from selenium.webdriver.chrome.options import Options

# %%
# Runs scrape in background
options = Options()
options.headless = True

# %%
driver.get(url)

driver.implicitly_wait(3)

'''
implicity_wait method is an efficient way of just waiting the necessary time to load element and run 
'''

driver.maximize_window() #maximizes window

# %%
table_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[3]/table
'''

index_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[1]/table
'''

# %%
element = driver.find_element("xpath", table_site)

#can be changed as needed such as  ID, class_, XPATH ou name (vc so vai usar um dos 4)

element_index = driver.find_element("xpath", index_site)

table_html = element.get_attribute('outerHTML')
index_html = element_index.get_attribute('outerHTML')

table = pd.read_html(table_html)[0]
indices = pd.read_html(index_html)[0]
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\3981532506.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table = pd.read_html(table_html)[0]
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\3981532506.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   indices = pd.read_html(index_html)[0]

# %%
driver.quit()

# %%
table
# Out:
#                    0                   1             2           3   \
# 0   AJUSTE ANTER. (3)  AJUSTE CORRIG. (4)  PREÇO ABERT.  PREÇO MÍN.
# 1           99.843,15           99.843,15         10398       10394
# 2           99.063,11           99.063,11         10386       10384
# 3           98.175,67           98.175,67         10372       10370
# 4           97.334,88           97.334,88         10375       10350
# 5           96.537,60           96.537,60         10375       10345
# 6           95.667,82           95.667,82         10380       10350
# 7           94.950,79           94.950,79         10400       10400
# 8           94.169,79           94.169,79         10405       10360
# 9           93.333,32           93.333,32         10450       10425
# 10          92.575,53           92.575,53         10485       10435
# 11          91.860,32           91.860,32         10525       10440
# 12          91.108,22           91.108,22         10545       10460
# 13          89.565,49           89.565,49         10640       10525
# 14          87.090,02           87.090,02         10755       10620
# 15          84.753,84           84.753,84         10860       10700
# 16          82.530,46           82.530,46         10940       10800
# 17          80.362,29           80.362,29         11015       10880
# 18          78.100,26           78.100,26         11090       10965
# 19          76.006,80           76.006,80         11135       11015
# 20          73.985,53           73.985,53         11215       11095
# 21          71.918,85           71.918,85         11265       11160
# 22          69.805,43           69.805,43         11340       11235
# 23          67.858,94           67.858,94         11405       11290
# 24          65.942,64           65.942,64         11430       11350
# 25          64.096,21           64.096,21         11500       11410
# 26          62.255,36           62.255,36         11540       11455
# 27          60.601,99           60.601,99         11565       11470
# 28          58.948,60           58.948,60         11580       11580
# 29          57.275,82           57.275,82         11590       11590
# 30          54.049,02           54.049,02         11690       11600
# 31          48.234,50           48.234,50         11740       11650
# 32          43.052,73           43.052,73         11760       11700
# 33          38.469,27           38.469,27         11830       11710
# 34          34.450,45           34.450,45          0000        0000
# 35          30.795,51           30.795,51         11810       11730
# 36          27.634,35           27.634,35          0000        0000
# 37          24.707,18           24.707,18          0000        0000
# 38          22.129,19           22.129,19          0000        0000
# 39          19.802,67           19.802,67          0000        0000
#
#             4           5           6          7           8   \
# 0   PREÇO MÁX.  PREÇO MÉD.  ÚLT. PREÇO     AJUSTE  VAR. PTOS.
# 1        10404       10396       10400  99.843,13       0,02-
# 2        10392       10386       10386  99.063,34       0,23+
# 3        10372       10370       10370  98.176,59       0,92+
# 4        10375       10367       10360  97.338,16       3,28+
# 5        10380       10360       10355  96.543,44       5,84+
# 6        10380       10359       10355  95.676,32       8,50+
# 7        10400       10400       10400  94.962,50      11,71+
# 8        10420       10384       10375  94.184,82      15,03+
# 9        10450       10434       10425  93.355,79      22,47+
# 10       10490       10462       10445  92.607,60      32,07+
# 11       10530       10489       10450  91.903,78      43,46+
# 12       10545       10528       10485  91.163,84      55,62+
# 13       10650       10575       10535  89.643,15      77,66+
# 14       10765       10669       10645  87.216,85     126,83+
# 15       10860       10761       10720  84.909,03     155,19+
# 16       10955       10853       10810  82.708,44     177,98+
# 17       11035       10962       10895  80.553,64     191,35+
# 18       11110       11028       10970  78.305,73     205,47+
# 19       11165       11074       11035  76.224,01     217,21+
# 20       11215       11145       11115  74.210,57     225,04+
# 21       11295       11224       11185  72.150,78     231,93+
# 22       11360       11275       11260  70.051,35     245,92+
# 23       11415       11348       11320  68.091,58     232,64+
# 24       11440       11408       11370  66.170,63     227,99+
# 25       11525       11467       11430  64.324,59     228,38+
# 26       11540       11501       11470  62.483,55     228,19+
# 27       11585       11514       11495  60.821,23     219,24+
# 28       11580       11580       11580  59.175,59     226,99+
# 29       11610       11601       11610  57.499,87     224,05+
# 30       11710       11632       11630  54.270,13     221,11+
# 31       11770       11689       11690  48.464,10     229,60+
# 32       11780       11767       11710  43.271,04     218,31+
# 33       11830       11756       11760  38.651,42     182,15+
# 34        0000        0000        0000  34.650,18     199,73+
# 35       11810       11785       11780  30.995,23     199,72+
# 36        0000        0000        0000  27.830,31     195,96+
# 37        0000        0000        0000  24.897,58     190,40+
# 38        0000        0000        0000  22.313,15     183,96+
# 39        0000        0000        0000  19.979,39     176,72+
#
#                  9               10
# 0   ÚLT. OF. COMPRA  ÚLT. OF. VENDA
# 1             10394           10400
# 2             10384           10386
# 3             10368           10372
# 4             10350           10360
# 5             10350           10355
# 6             10355           10370
# 7             10365           10380
# 8             10370           10375
# 9             10400            0000
# 10            10430           10450
# 11            10450           10460
# 12            10470           10495
# 13            10535           10550
# 14            10635           10650
# 15            10720           10725
# 16            10810           10825
# 17            10895           10900
# 18             0000            0000
# 19            11030           11045
# 20             0000            0000
# 21            11170           11185
# 22             0000            0000
# 23            11290           11320
# 24             0000            0000
# 25             0000            0000
# 26             0000            0000
# 27            11475           11495
# 28             0000            0000
# 29             0000           11620
# 30            11610           11640
# 31            11670           11690
# 32             0000            0000
# 33            11740           11760
# 34            11690           11870
# 35            11750           11780
# 36             0000            0000
# 37            11640            0000
# 38            11620            0000
# 39             0000            0000

# %%
table.columns = table.loc[0]

table = table['ÚLT. PREÇO']

table = table.drop(0, axis = 0)

indices.columns = indices.loc[0]

indice_di = indices['VENCTO']

indices = indices.drop(0, axis = 0)

table.index = indices['VENCTO']

table = table.astype(int)

table = table[table != 0]

table = table/1000

print(table)
# Out:
# VENCTO
# M24    10.400
# N24    10.386
# Q24    10.370
# U24    10.360
# V24    10.355
# X24    10.355
# Z24    10.400
# F25    10.375
# G25    10.425
# H25    10.445
# J25    10.450
# K25    10.485
# N25    10.535
# V25    10.645
# F26    10.720
# J26    10.810
# N26    10.895
# V26    10.970
# F27    11.035
# J27    11.115
# N27    11.185
# V27    11.260
# F28    11.320
# J28    11.370
# N28    11.430
# V28    11.470
# F29    11.495
# J29    11.580
# N29    11.610
# F30    11.630
# F31    11.690
# F32    11.710
# F33    11.760
# F35    11.780
# Name: ÚLT. PREÇO, dtype: float64

# %%
driver.quit()

# %% [markdown]
# # Data preprocessing

# %%
legenda = pd.Series(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                    index = ['F', 'G', 'H', 'J', 'K', 'M', 'N', 'Q', 'U', 'V', 'X', 'Z'])

lista_datas = []

# %%
for indice in table.index:

    letra = indice[0]
    
    legenda["F"]
    ano = indice[1:3]

    mes = legenda[letra]

    data = f"{mes}-{ano}"

    data = datetime.strptime(data, "%b-%y")

    lista_datas.append(data)


table.index = lista_datas  

table
# Out:
# 2024-06-01    10.400
# 2024-07-01    10.386
# 2024-08-01    10.370
# 2024-09-01    10.360
# 2024-10-01    10.355
# 2024-11-01    10.355
# 2024-12-01    10.400
# 2025-01-01    10.375
# 2025-02-01    10.425
# 2025-03-01    10.445
# 2025-04-01    10.450
# 2025-05-01    10.485
# 2025-07-01    10.535
# 2025-10-01    10.645
# 2026-01-01    10.720
# 2026-04-01    10.810
# 2026-07-01    10.895
# 2026-10-01    10.970
# 2027-01-01    11.035
# 2027-04-01    11.115
# 2027-07-01    11.185
# 2027-10-01    11.260
# 2028-01-01    11.320
# 2028-04-01    11.370
# 2028-07-01    11.430
# 2028-10-01    11.470
# 2029-01-01    11.495
# 2029-04-01    11.580
# 2029-07-01    11.610
# 2030-01-01    11.630
# 2031-01-01    11.690
# 2032-01-01    11.710
# 2033-01-01    11.760
# 2035-01-01    11.780
# Name: ÚLT. PREÇO, dtype: float64

# %% [markdown]
# ## Mini-Indice - WIN

# %%
product = 'WIN'

# %%
url = f'''
https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/SistemaPregao1.asp?pagetype=pop&caminho=Resumo%20
Estat%EDstico%20-%20Sistema%20Preg%E3o&Data={date}&Mercadoria={product}
'''

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install())) 

driver.get(url)

driver.implicitly_wait(3)


driver.maximize_window() 

table_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[3]/table
'''

index_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[1]/table
'''

element = driver.find_element("xpath", table_site)

#can be changed as needed such as  ID, class_, XPATH ou name (vc so vai usar um dos 4)

element_index = driver.find_element("xpath", index_site)

table_html = element.get_attribute('outerHTML')
index_html = element_index.get_attribute('outerHTML')

table = pd.read_html(table_html)[0]
indices = pd.read_html(index_html)[0]

driver.quit()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\3436761226.py:27: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table = pd.read_html(table_html)[0]
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\3436761226.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   indices = pd.read_html(index_html)[0]

# %%
table
# Out:
#                0           1           2           3           4        5  \
# 0   PREÇO ABERT.  PREÇO MÍN.  PREÇO MÁX.  PREÇO MÉD.  ÚLT. PREÇO   AJUSTE
# 1        124.810     124.550     125.085     124.845     125.000  124.959
# 2        126.975     126.570     127.070     126.799     127.030  126.963
# 3        128.765     128.765     129.000     128.788     129.000  128.869
# 4        129.780     129.700     129.780     129.740     129.700  130.792
# 5              0           0           0           0           0  132.548
# 6              0           0           0           0           0  134.581
# 7              0           0           0           0           0  136.633
# 8              0           0           0           0           0  138.598
# 9              0           0           0           0           0  140.912
# 10             0           0           0           0           0  143.228
# 11             0           0           0           0           0  145.473
# 12             0           0           0           0           0  147.658
# 13             0           0           0           0           0  150.062
#
#          6           7                8               9
# 0   OSCIL.  VAR. PTOS.  ÚLT. OF. COMPRA  ÚLT. OF. VENDA
# 1     0,1+        105+          124.990         125.000
# 2     0,1+        104+          126.905         127.035
# 3     0,1+         99+          128.500         130.530
# 4     0,7-         91+                0         131.520
# 5       00         75+                0               0
# 6       00         40+                0               0
# 7       00          2+                0               0
# 8       00         42-                0               0
# 9       00         95-                0               0
# 10      00        133-                0               0
# 11      00        167-                0               0
# 12      00        200-                0               0
# 13      00        224-                0               0

# %%
table.columns = table.loc[0]

table = table['AJUSTE']

table = table.drop(0, axis = 0)

indices.columns = indices.loc[0]

indice_di = indices['VENCTO']

indices = indices.drop(0, axis = 0)

table.index = indices['VENCTO']

table = table[table != "0"]

print(table)
# Out:
# VENCTO
# M24    124.959
# Q24    126.963
# V24    128.869
# Z24    130.792
# G25    132.548
# J25    134.581
# M25    136.633
# Q25    138.598
# V25    140.912
# Z25    143.228
# G26    145.473
# J26    147.658
# M26    150.062
# Name: AJUSTE, dtype: object

# %%
tabela.columns = tabela.loc[0]

tabela = tabela['AJUSTE']

tabela = tabela.drop(0, axis = 0)

indice.columns = indice.loc[0]

indice_di = indice['VENCTO']

indice = indice.drop(0, axis = 0)

tabela.index = indice['VENCTO']

tabela = tabela[tabela != "0"]

print(tabela)

# %% [markdown]
# # Mini-Dolar WDO

# %%
product = 'WDO'

# %%
url = f'''
https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/SistemaPregao1.asp?pagetype=pop&caminho=Resumo%20
Estat%EDstico%20-%20Sistema%20Preg%E3o&Data={date}&Mercadoria={product}
'''

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install())) 

driver.get(url)

driver.implicitly_wait(3)


driver.maximize_window() 

table_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[3]/table
'''

index_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[1]/table
'''

element = driver.find_element("xpath", table_site)

#can be changed as needed such as  ID, class_, XPATH ou name (vc so vai usar um dos 4)

element_index = driver.find_element("xpath", index_site)

table_html = element.get_attribute('outerHTML')
index_html = element_index.get_attribute('outerHTML')

table = pd.read_html(table_html)[0]
indices = pd.read_html(index_html)[0]

driver.quit()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\3436761226.py:27: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table = pd.read_html(table_html)[0]
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\3436761226.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   indices = pd.read_html(index_html)[0]

# %%
table
# Out:
#                0           1           2           3           4           5  \
# 0   PREÇO ABERT.  PREÇO MÍN.  PREÇO MÁX.  PREÇO MÉD.  ÚLT. PREÇO      AJUSTE
# 1      5.160,000   5.156,000   5.185,000   5.169,676   5.173,500  5.173,7820
# 2      5.179,000   5.171,500   5.199,000   5.183,385   5.187,500  5.188,6810
# 3      5.199,500   5.190,000   5.209,000   5.202,073   5.203,500  5.206,3190
# 4      5.198,000   5.195,500   5.232,500   5.210,535   5.209,500  5.222,0560
# 5           0000        0000        0000        0000        0000  5.236,6210
# 6           0000        0000        0000        0000        0000  5.253,4590
# 7           0000        0000        0000        0000        0000  5.265,8470
# 8           0000        0000        0000        0000        0000  5.279,0940
# 9           0000        0000        0000        0000        0000  5.295,8150
# 10          0000        0000        0000        0000        0000  5.311,8480
# 11          0000        0000        0000        0000        0000  5.327,5370
# 12          0000        0000        0000        0000        0000  5.340,7940
# 13          0000        0000        0000        0000        0000  5.380,6660
# 14          0000        0000        0000        0000        0000  5.451,2840
# 15          0000        0000        0000        0000        0000  5.520,0670
# 16          0000        0000        0000        0000        0000  5.595,6270
#
#              6                7               8
# 0   VAR. PTOS.  ÚLT. OF. COMPRA  ÚLT. OF. VENDA
# 1      2,4110+        5.172,500       5.173,500
# 2      2,2850+        5.186,500       5.188,500
# 3      2,2910+        5.203,500       5.207,000
# 4      2,0030+        5.206,000       5.223,000
# 5      1,7730+        5.217,500       5.286,500
# 6      1,7700+             0000            0000
# 7      1,5440+             0000            0000
# 8      1,3240+             0000            0000
# 9      0,5000+             0000            0000
# 10     0,2630+             0000            0000
# 11     1,3420-             0000            0000
# 12     2,1440-             0000       5.340,000
# 13     3,7930-             0000            0000
# 14     5,4080-             0000            0000
# 15     7,5920-             0000            0000
# 16     9,3930-             0000            0000

# %%
table.columns = table.loc[0]

table = table['AJUSTE']

table = table.drop(0, axis = 0)

indices.columns = indices.loc[0]

indice_di = indices['VENCTO']

indices = indices.drop(0, axis = 0)

table.index = indices['VENCTO']

table = table[table != "0"]

print(table)
# Out:
# VENCTO
# M24    5.173,7820
# N24    5.188,6810
# Q24    5.206,3190
# U24    5.222,0560
# V24    5.236,6210
# X24    5.253,4590
# Z24    5.265,8470
# F25    5.279,0940
# G25    5.295,8150
# H25    5.311,8480
# J25    5.327,5370
# K25    5.340,7940
# N25    5.380,6660
# V25    5.451,2840
# F26    5.520,0670
# J26    5.595,6270
# Name: AJUSTE, dtype: object

# %% [markdown]
# # EURO

# %%
product = 'EUR'
url = f'''
https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/SistemaPregao1.asp?pagetype=pop&caminho=Resumo%20
Estat%EDstico%20-%20Sistema%20Preg%E3o&Data={date}&Mercadoria={product}
'''

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install())) 

driver.get(url)

driver.implicitly_wait(3)


driver.maximize_window() 

table_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[3]/table
'''

index_site = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[1]/table
'''

element = driver.find_element("xpath", table_site)

#can be changed as needed such as  ID, class_, XPATH ou name (vc so vai usar um dos 4)

element_index = driver.find_element("xpath", index_site)

table_html = element.get_attribute('outerHTML')
index_html = element_index.get_attribute('outerHTML')

table = pd.read_html(table_html)[0]
indices = pd.read_html(index_html)[0]

driver.quit()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\848719876.py:33: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table = pd.read_html(table_html)[0]
# C:\Users\Home\AppData\Local\Temp\ipykernel_25524\848719876.py:34: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   indices = pd.read_html(index_html)[0]

# %%
table
# Out:
#               0           1           2           3           4           5  \
# 0  PREÇO ABERT.  PREÇO MÍN.  PREÇO MÁX.  PREÇO MÉD.  ÚLT. PREÇO      AJUSTE
# 1          0000        0000        0000        0000        0000  5.617,7960
# 2          0000        0000        0000        0000        0000  5.640,2570
# 3          0000        0000        0000        0000        0000  5.667,9270
# 4          0000        0000        0000        0000        0000  5.693,5710
# 5          0000        0000        0000        0000        0000  5.717,8930
#
#             6                7               8
# 0  VAR. PTOS.  ÚLT. OF. COMPRA  ÚLT. OF. VENDA
# 1     6,3880+             0000            0000
# 2     5,1390+             0000            0000
# 3     5,0080+             0000            0000
# 4     5,0970+             0000            0000
# 5     5,0510+             0000            0000

# %%
table.columns = table.loc[0]

table = table['AJUSTE']

table = table.drop(0, axis = 0)

indices.columns = indices.loc[0]

indice_di = indices['VENCTO']

indices = indices.drop(0, axis = 0)

table.index = indices['VENCTO']

table = table[table != "0"]

print(table)
# Out:
# VENCTO
# M24    5.617,7960
# N24    5.640,2570
# Q24    5.667,9270
# U24    5.693,5710
# V24    5.717,8930
# Name: AJUSTE, dtype: object
